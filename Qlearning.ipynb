# %%
# %load_ext autoreload
# %autoreload 2


import matplotlib.pyplot as plt
import Arena
#from MCTS import MCTS
from connect4.Connect4Game import Connect4Game, display
from connect4.Connect4Players import *
from Qlearning import QLearningPlayer 
import numpy as np
from utils import *


"""
use this script to play any two agents against each other, or play manually with
any agent.
"""
g = Connect4Game(6)

# all players
rp = RandomPlayer(g).play
ql = QLearningPlayer(g).learning
#QL= QLearningPlayer(g).learned

#gp = GreedyOthelloPlayer(g).play
#hp = HumanConnect4Player(g).play

op=OneStepLookaheadConnect4Player(g).play

# arena_rp_op = Arena.Arena(rp, op, g, display=display)
# print(arena_rp_op.playGames(2, verbose=True))

# arena_rp_hp = Arena.Arena(rp, hp, g, display=display)
# print(arena_rp_hp.playGames(2, verbose=True))

toW=[]

for i in np.arange(10): 
    print(i)
    arena_rp_hp = Arena.Arena(rp, ql, g, display=display)
    oneWon, twoWon, draws=arena_rp_hp.playGames(100, verbose=False) 
    toW.append(twoWon)

# print(oneWon, twoWon, draws)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 0
#
# ena.playGames  |                                | 1/100
# ena.playGames  |                                | 2/100
# ena.playGames  |                                | 3/100
# ena.playGames  |#                               | 4/100
# ena.playGames  |#                               | 5/100
# ena.playGames  |#                               | 6/100
# ena.playGames  |##                              | 7/100
# ena.playGames  |##                              | 8/100
# ena.playGames  |##                              | 9/100
# ena.playGames  |###                             | 10/100
# ena.playGames  |###                             | 11/100
# ena.playGames  |###                             | 12/100
# ena.playGames  |####                            | 13/100
# ena.playGames  |####                            | 14/100
# ena.playGames  |####                            | 15/100
# ena.playGames  |#####                           | 16/100
# ena.playGames  |#####                           | 17/100
# ena.playGames  |#####                           | 18/100
# ena.playGames  |######                          | 19/100
# ena.playGames  |######                          | 20/100
# ena.playGames  |######                          | 21/100
# ena.playGames  |#######                         | 22/100
# ena.playGames  |#######                         | 23/100
# ena.playGames  |#######                         | 24/100
# ena.playGames  |########                        | 25/100
# ena.playGames  |########                        | 26/100
# ena.playGames  |########                        | 27/100
# ena.playGames  |########                        | 28/100
# ena.playGames  |#########                       | 29/100
# ena.playGames  |#########                       | 30/100
# ena.playGames  |#########                       | 31/100
# ena.playGames  |##########                      | 32/100
# ena.playGames  |##########                      | 33/100
# ena.playGames  |##########                      | 34/100
# ena.playGames  |###########                     | 35/100
# ena.playGames  |###########                     | 36/100
# ena.playGames  |###########                     | 37/100
# ena.playGames  |############                    | 38/100
# ena.playGames  |############                    | 39/100
# ena.playGames  |############                    | 40/100
# ena.playGames  |#############                   | 41/100
# ena.playGames  |#############                   | 42/100
# ena.playGames  |#############                   | 43/100
# ena.playGames  |##############                  | 44/100
# ena.playGames  |##############                  | 45/100
# ena.playGames  |##############                  | 46/100
# ena.playGames  |###############                 | 47/100
# ena.playGames  |###############                 | 48/100
# ena.playGames  |###############                 | 49/100
# ena.playGames  |################                | 50/100
# ena.playGames  |################                | 51/100
# ena.playGames  |################                | 52/100
# ena.playGames  |################                | 53/100
# ena.playGames  |#################               | 54/100
# ena.playGames  |#################               | 55/100
# ena.playGames  |#################               | 56/100
# ena.playGames  |##################              | 57/100
# ena.playGames  |##################              | 58/100
# ena.playGames  |##################              | 59/100
# ena.playGames  |###################             | 60/100
# ena.playGames  |###################             | 61/100
# ena.playGames  |###################             | 62/100
# ena.playGames  |####################            | 63/100
# ena.playGames  |####################            | 64/100
# ena.playGames  |####################            | 65/100
# ena.playGames  |#####################           | 66/100
# ena.playGames  |#####################           | 67/100
# ena.playGames  |#####################           | 68/100
# ena.playGames  |######################          | 69/100
# ena.playGames  |######################          | 70/100
# ena.playGames  |######################          | 71/100
# ena.playGames  |#######################         | 72/100
# ena.playGames  |#######################         | 73/100
# ena.playGames  |#######################         | 74/100
# ena.playGames  |########################        | 75/100
# ena.playGames  |########################        | 76/100
# ena.playGames  |########################        | 77/100
# ena.playGames  |########################        | 78/100
# ena.playGames  |#########################       | 79/100
# ena.playGames  |#########################       | 80/100
# ena.playGames  |#########################       | 81/100
# ena.playGames  |##########################      | 82/100
# ena.playGames  |##########################      | 83/100
# ena.playGames  |##########################      | 84/100
# ena.playGames  |###########################     | 85/100
# ena.playGames  |###########################     | 86/100
# ena.playGames  |###########################     | 87/100
# ena.playGames  |############################    | 88/100
# ena.playGames  |############################    | 89/100
# ena.playGames  |############################    | 90/100
# ena.playGames  |#############################   | 91/100
# ena.playGames  |#############################   | 92/100
# ena.playGames  |#############################   | 93/100
# ena.playGames  |##############################  | 94/100
# ena.playGames  |##############################  | 95/100
# ena.playGames  |##############################  | 96/100
# ena.playGames  |############################### | 97/100
# ena.playGames  |############################### | 98/100
# ena.playGames  |############################### | 99/100
#  Arena.playGames  |################################| 100/100
# 1
#
# ena.playGames  |                                | 1/100
# ena.playGames  |                                | 2/100
# ena.playGames  |                                | 3/100
# ena.playGames  |#                               | 4/100
# ena.playGames  |#                               | 5/100
# ena.playGames  |#                               | 6/100
# ena.playGames  |##                              | 7/100
# ena.playGames  |##                              | 8/100
# ena.playGames  |##                              | 9/100
# ena.playGames  |###                             | 10/100
# ena.playGames  |###                             | 11/100
# ena.playGames  |###                             | 12/100
# ena.playGames  |####                            | 13/100
# ena.playGames  |####                            | 14/100
# ena.playGames  |####                            | 15/100
# ena.playGames  |#####                           | 16/100
# ena.playGames  |#####                           | 17/100
# ena.playGames  |#####                           | 18/100
# ena.playGames  |######                          | 19/100
# ena.playGames  |######                          | 20/100
# ena.playGames  |######                          | 21/100
# ena.playGames  |#######                         | 22/100
# ena.playGames  |#######                         | 23/100
# ena.playGames  |#######                         | 24/100
# ena.playGames  |########                        | 25/100
# ena.playGames  |########                        | 26/100
# ena.playGames  |########                        | 27/100
# ena.playGames  |########                        | 28/100
# ena.playGames  |#########                       | 29/100
# ena.playGames  |#########                       | 30/100
# ena.playGames  |#########                       | 31/100
# ena.playGames  |##########                      | 32/100
# ena.playGames  |##########                      | 33/100
# ena.playGames  |##########                      | 34/100
# ena.playGames  |###########                     | 35/100
# ena.playGames  |###########                     | 36/100
# ena.playGames  |###########                     | 37/100
# ena.playGames  |############                    | 38/100
# ena.playGames  |############                    | 39/100
# ena.playGames  |############                    | 40/100
# ena.playGames  |#############                   | 41/100
# ena.playGames  |#############                   | 42/100
# ena.playGames  |#############                   | 43/100
# ena.playGames  |##############                  | 44/100
# ena.playGames  |##############                  | 45/100
# ena.playGames  |##############                  | 46/100
# ena.playGames  |###############                 | 47/100
# ena.playGames  |###############                 | 48/100
# ena.playGames  |###############                 | 49/100
# ena.playGames  |################                | 50/100
# ena.playGames  |################                | 51/100
# ena.playGames  |################                | 52/100
# ena.playGames  |################                | 53/100
# ena.playGames  |#################               | 54/100
# ena.playGames  |#################               | 55/100
# ena.playGames  |#################               | 56/100
# ena.playGames  |##################              | 57/100
# ena.playGames  |##################              | 58/100
# ena.playGames  |##################              | 59/100
# ena.playGames  |###################             | 60/100
# ena.playGames  |###################             | 61/100
# ena.playGames  |###################             | 62/100
# ena.playGames  |####################            | 63/100
# ena.playGames  |####################            | 64/100
# ena.playGames  |####################            | 65/100
# ena.playGames  |#####################           | 66/100
# ena.playGames  |#####################           | 67/100
# ena.playGames  |#####################           | 68/100
# ena.playGames  |######################          | 69/100
# ena.playGames  |######################          | 70/100
# ena.playGames  |######################          | 71/100
# ena.playGames  |#######################         | 72/100
# ena.playGames  |#######################         | 73/100
# ena.playGames  |#######################         | 74/100
# ena.playGames  |########################        | 75/100
# ena.playGames  |########################        | 76/100
# ena.playGames  |########################        | 77/100
# ena.playGames  |########################        | 78/100
# ena.playGames  |#########################       | 79/100
# ena.playGames  |#########################       | 80/100
# ena.playGames  |#########################       | 81/100
# ena.playGames  |##########################      | 82/100
# ena.playGames  |##########################      | 83/100
# ena.playGames  |##########################      | 84/100
# ena.playGames  |###########################     | 85/100
# ena.playGames  |###########################     | 86/100
# ena.playGames  |###########################     | 87/100
# ena.playGames  |############################    | 88/100
# ena.playGames  |############################    | 89/100
# ena.playGames  |############################    | 90/100
# ena.playGames  |#############################   | 91/100
# ena.playGames  |#############################   | 92/100
# ena.playGames  |#############################   | 93/100
# ena.playGames  |##############################  | 94/100
# ena.playGames  |##############################  | 95/100
# ena.playGames  |##############################  | 96/100
# ena.playGames  |############################### | 97/100
# ena.playGames  |############################### | 98/100
# ena.playGames  |############################### | 99/100
#  Arena.playGames  |################################| 100/100
# 2
#
# ena.playGames  |                                | 1/100
# ena.playGames  |                                | 2/100
# ena.playGames  |                                | 3/100
# ena.playGames  |#                               | 4/100
# ena.playGames  |#                               | 5/100
# ena.playGames  |#                               | 6/100
# ena.playGames  |##                              | 7/100
# ena.playGames  |##                              | 8/100
# ena.playGames  |##                              | 9/100
# ena.playGames  |###                             | 10/100
# ena.playGames  |###                             | 11/100
# ena.playGames  |###                             | 12/100
# ena.playGames  |####                            | 13/100
# ena.playGames  |####                            | 14/100
# ena.playGames  |####                            | 15/100
# ena.playGames  |#####                           | 16/100
# ena.playGames  |#####                           | 17/100
# ena.playGames  |#####                           | 18/100
# ena.playGames  |######                          | 19/100
# ena.playGames  |######                          | 20/100
# ena.playGames  |######                          | 21/100
# ena.playGames  |#######                         | 22/100
# ena.playGames  |#######                         | 23/100
# ena.playGames  |#######                         | 24/100
# ena.playGames  |########                        | 25/100
# ena.playGames  |########                        | 26/100
# ena.playGames  |########                        | 27/100
# ena.playGames  |########                        | 28/100
# ena.playGames  |#########                       | 29/100
# ena.playGames  |#########                       | 30/100
# ena.playGames  |#########                       | 31/100
# ena.playGames  |##########                      | 32/100
# ena.playGames  |##########                      | 33/100
# ena.playGames  |##########                      | 34/100
# ena.playGames  |###########                     | 35/100
# ena.playGames  |###########                     | 36/100
# ena.playGames  |###########                     | 37/100
# ena.playGames  |############                    | 38/100
# ena.playGames  |############                    | 39/100
# ena.playGames  |############                    | 40/100
# ena.playGames  |#############                   | 41/100
# ena.playGames  |#############                   | 42/100
# ena.playGames  |#############                   | 43/100
# ena.playGames  |##############                  | 44/100
# ena.playGames  |##############                  | 45/100
# ena.playGames  |##############                  | 46/100
# ena.playGames  |###############                 | 47/100
# ena.playGames  |###############                 | 48/100
# ena.playGames  |###############                 | 49/100
# ena.playGames  |################                | 50/100
# ena.playGames  |################                | 51/100
# ena.playGames  |################                | 52/100
# ena.playGames  |################                | 53/100
# ena.playGames  |#################               | 54/100
# ena.playGames  |#################               | 55/100
# ena.playGames  |#################               | 56/100
# ena.playGames  |##################              | 57/100
# ena.playGames  |##################              | 58/100
# ena.playGames  |##################              | 59/100
# ena.playGames  |###################             | 60/100
# ena.playGames  |###################             | 61/100
# ena.playGames  |###################             | 62/100
# ena.playGames  |####################            | 63/100
# ena.playGames  |####################            | 64/100
# ena.playGames  |####################            | 65/100
# ena.playGames  |#####################           | 66/100
# ena.playGames  |#####################           | 67/100
# ena.playGames  |#####################           | 68/100
# ena.playGames  |######################          | 69/100
# ena.playGames  |######################          | 70/100
# ena.playGames  |######################          | 71/100
# ena.playGames  |#######################         | 72/100
# ena.playGames  |#######################         | 73/100
# ena.playGames  |#######################         | 74/100
# ena.playGames  |########################        | 75/100
# ena.playGames  |########################        | 76/100
# ena.playGames  |########################        | 77/100
# ena.playGames  |########################        | 78/100
# ena.playGames  |#########################       | 79/100
# ena.playGames  |#########################       | 80/100
# ena.playGames  |#########################       | 81/100
# ena.playGames  |##########################      | 82/100
# ena.playGames  |##########################      | 83/100
# ena.playGames  |##########################      | 84/100
# ena.playGames  |###########################     | 85/100
# ena.playGames  |###########################     | 86/100
# ena.playGames  |###########################     | 87/100
# ena.playGames  |############################    | 88/100
# ena.playGames  |############################    | 89/100
# ena.playGames  |############################    | 90/100
# ena.playGames  |#############################   | 91/100
# ena.playGames  |#############################   | 92/100
# ena.playGames  |#############################   | 93/100
# ena.playGames  |##############################  | 94/100
# ena.playGames  |##############################  | 95/100
# ena.playGames  |##############################  | 96/100
# ena.playGames  |############################### | 97/100
# ena.playGames  |############################### | 98/100
# ena.playGames  |############################### | 99/100
#  Arena.playGames  |################################| 100/100
# 3
#
# ena.playGames  |                                | 1/100
# ena.playGames  |                                | 2/100
# ena.playGames  |                                | 3/100
# ena.playGames  |#                               | 4/100
# ena.playGames  |#                               | 5/100
# ena.playGames  |#                               | 6/100
# ena.playGames  |##                              | 7/100
# ena.playGames  |##                              | 8/100
# ena.playGames  |##                              | 9/100
# ena.playGames  |###                             | 10/100
# ena.playGames  |###                             | 11/100
# ena.playGames  |###                             | 12/100
# ena.playGames  |####                            | 13/100
# ena.playGames  |####                            | 14/100
# ena.playGames  |####                            | 15/100
# ena.playGames  |#####                           | 16/100
# ena.playGames  |#####                           | 17/100
# ena.playGames  |#####                           | 18/100
# ena.playGames  |######                          | 19/100
# ena.playGames  |######                          | 20/100
# ena.playGames  |######                          | 21/100
# ena.playGames  |#######                         | 22/100
# ena.playGames  |#######                         | 23/100
# ena.playGames  |#######                         | 24/100
# ena.playGames  |########                        | 25/100
# ena.playGames  |########                        | 26/100
# ena.playGames  |########                        | 27/100
# ena.playGames  |########                        | 28/100
# ena.playGames  |#########                       | 29/100
# ena.playGames  |#########                       | 30/100
# ena.playGames  |#########                       | 31/100
# ena.playGames  |##########                      | 32/100
# ena.playGames  |##########                      | 33/100
# ena.playGames  |##########                      | 34/100
# ena.playGames  |###########                     | 35/100
# ena.playGames  |###########                     | 36/100
# ena.playGames  |###########                     | 37/100
# ena.playGames  |############                    | 38/100
# ena.playGames  |############                    | 39/100
# ena.playGames  |############                    | 40/100
# ena.playGames  |#############                   | 41/100
# ena.playGames  |#############                   | 42/100
# ena.playGames  |#############                   | 43/100
# ena.playGames  |##############                  | 44/100
# ena.playGames  |##############                  | 45/100
# ena.playGames  |##############                  | 46/100
# ena.playGames  |###############                 | 47/100
# ena.playGames  |###############                 | 48/100
# ena.playGames  |###############                 | 49/100
# ena.playGames  |################                | 50/100
# ena.playGames  |################                | 51/100
# ena.playGames  |################                | 52/100
# ena.playGames  |################                | 53/100
# ena.playGames  |#################               | 54/100
# ena.playGames  |#################               | 55/100
# ena.playGames  |#################               | 56/100
# ena.playGames  |##################              | 57/100
# ena.playGames  |##################              | 58/100
# ena.playGames  |##################              | 59/100
# ena.playGames  |###################             | 60/100
# ena.playGames  |###################             | 61/100
# ena.playGames  |###################             | 62/100
# ena.playGames  |####################            | 63/100
# ena.playGames  |####################            | 64/100
# ena.playGames  |####################            | 65/100
# ena.playGames  |#####################           | 66/100
# ena.playGames  |#####################           | 67/100
# ena.playGames  |#####################           | 68/100
# ena.playGames  |######################          | 69/100
# ena.playGames  |######################          | 70/100
# ena.playGames  |######################          | 71/100
# ena.playGames  |#######################         | 72/100
# ena.playGames  |#######################         | 73/100
# ena.playGames  |#######################         | 74/100
# ena.playGames  |########################        | 75/100
# ena.playGames  |########################        | 76/100
# ena.playGames  |########################        | 77/100
# ena.playGames  |########################        | 78/100
# ena.playGames  |#########################       | 79/100
# ena.playGames  |#########################       | 80/100
# ena.playGames  |#########################       | 81/100
# ena.playGames  |##########################      | 82/100
# ena.playGames  |##########################      | 83/100
# ena.playGames  |##########################      | 84/100
# ena.playGames  |###########################     | 85/100
# ena.playGames  |###########################     | 86/100
# ena.playGames  |###########################     | 87/100
# ena.playGames  |############################    | 88/100
# ena.playGames  |############################    | 89/100
# ena.playGames  |############################    | 90/100
# ena.playGames  |#############################   | 91/100
# ena.playGames  |#############################   | 92/100
# ena.playGames  |#############################   | 93/100
# ena.playGames  |##############################  | 94/100
# ena.playGames  |##############################  | 95/100
# ena.playGames  |##############################  | 96/100
# ena.playGames  |############################### | 97/100
# ena.playGames  |############################### | 98/100
# ena.playGames  |############################### | 99/100
#  Arena.playGames  |################################| 100/100
# 4
#
# ena.playGames  |                                | 1/100
# ena.playGames  |                                | 2/100
# ena.playGames  |                                | 3/100
# ena.playGames  |#                               | 4/100
# ena.playGames  |#                               | 5/100
# ena.playGames  |#                               | 6/100
# ena.playGames  |##                              | 7/100
# ena.playGames  |##                              | 8/100
# ena.playGames  |##                              | 9/100
# ena.playGames  |###                             | 10/100
# ena.playGames  |###                             | 11/100
# ena.playGames  |###                             | 12/100
# ena.playGames  |####                            | 13/100
# ena.playGames  |####                            | 14/100
# ena.playGames  |####                            | 15/100
# ena.playGames  |#####                           | 16/100
# ena.playGames  |#####                           | 17/100
# ena.playGames  |#####                           | 18/100
# ena.playGames  |######                          | 19/100
# ena.playGames  |######                          | 20/100
# ena.playGames  |######                          | 21/100
# ena.playGames  |#######                         | 22/100
# ena.playGames  |#######                         | 23/100
# ena.playGames  |#######                         | 24/100
# ena.playGames  |########                        | 25/100
# ena.playGames  |########                        | 26/100
# ena.playGames  |########                        | 27/100
# ena.playGames  |########                        | 28/100
# ena.playGames  |#########                       | 29/100
# ena.playGames  |#########                       | 30/100
# ena.playGames  |#########                       | 31/100
# ena.playGames  |##########                      | 32/100
# ena.playGames  |##########                      | 33/100
# ena.playGames  |##########                      | 34/100
# ena.playGames  |###########                     | 35/100
# ena.playGames  |###########                     | 36/100
# ena.playGames  |###########                     | 37/100
# ena.playGames  |############                    | 38/100
# ena.playGames  |############                    | 39/100
# ena.playGames  |############                    | 40/100
# ena.playGames  |#############                   | 41/100
# ena.playGames  |#############                   | 42/100
# ena.playGames  |#############                   | 43/100
# ena.playGames  |##############                  | 44/100
# ena.playGames  |##############                  | 45/100
# ena.playGames  |##############                  | 46/100
# ena.playGames  |###############                 | 47/100
# ena.playGames  |###############                 | 48/100
# ena.playGames  |###############                 | 49/100
# ena.playGames  |################                | 50/100
# ena.playGames  |################                | 51/100
# ena.playGames  |################                | 52/100
# ena.playGames  |################                | 53/100
# ena.playGames  |#################               | 54/100
# ena.playGames  |#################               | 55/100
# ena.playGames  |#################               | 56/100
# ena.playGames  |##################              | 57/100
# ena.playGames  |##################              | 58/100
# ena.playGames  |##################              | 59/100
# ena.playGames  |###################             | 60/100
# ena.playGames  |###################             | 61/100
# ena.playGames  |###################             | 62/100
# ena.playGames  |####################            | 63/100
# ena.playGames  |####################            | 64/100
# ena.playGames  |####################            | 65/100
# ena.playGames  |#####################           | 66/100
# ena.playGames  |#####################           | 67/100
# ena.playGames  |#####################           | 68/100
# ena.playGames  |######################          | 69/100
# ena.playGames  |######################          | 70/100
# ena.playGames  |######################          | 71/100
# ena.playGames  |#######################         | 72/100
# ena.playGames  |#######################         | 73/100
# ena.playGames  |#######################         | 74/100
# ena.playGames  |########################        | 75/100
# ena.playGames  |########################        | 76/100
# ena.playGames  |########################        | 77/100
# ena.playGames  |########################        | 78/100
# ena.playGames  |#########################       | 79/100
# ena.playGames  |#########################       | 80/100
# ena.playGames  |#########################       | 81/100
# ena.playGames  |##########################      | 82/100
# ena.playGames  |##########################      | 83/100
# ena.playGames  |##########################      | 84/100
# ena.playGames  |###########################     | 85/100
# ena.playGames  |###########################     | 86/100
# ena.playGames  |###########################     | 87/100
# ena.playGames  |############################    | 88/100
# ena.playGames  |############################    | 89/100
# ena.playGames  |############################    | 90/100
# ena.playGames  |#############################   | 91/100
# ena.playGames  |#############################   | 92/100
# ena.playGames  |#############################   | 93/100
# ena.playGames  |##############################  | 94/100
# ena.playGames  |##############################  | 95/100
# ena.playGames  |##############################  | 96/100
# ena.playGames  |############################### | 97/100
# ena.playGames  |############################### | 98/100
# ena.playGames  |############################### | 99/100
#  Arena.playGames  |################################| 100/100
# 5
#
# ena.playGames  |                                | 1/100
# ena.playGames  |                                | 2/100
# ena.playGames  |                                | 3/100
# ena.playGames  |#                               | 4/100
# ena.playGames  |#                               | 5/100
# ena.playGames  |#                               | 6/100
# ena.playGames  |##                              | 7/100
# ena.playGames  |##                              | 8/100
# ena.playGames  |##                              | 9/100
# ena.playGames  |###                             | 10/100
# ena.playGames  |###                             | 11/100
# ena.playGames  |###                             | 12/100
# ena.playGames  |####                            | 13/100
# ena.playGames  |####                            | 14/100
# ena.playGames  |####                            | 15/100
# ena.playGames  |#####                           | 16/100
# ena.playGames  |#####                           | 17/100
# ena.playGames  |#####                           | 18/100
# ena.playGames  |######                          | 19/100
# ena.playGames  |######                          | 20/100
# ena.playGames  |######                          | 21/100
# ena.playGames  |#######                         | 22/100
# ena.playGames  |#######                         | 23/100
# ena.playGames  |#######                         | 24/100
# ena.playGames  |########                        | 25/100
# ena.playGames  |########                        | 26/100
# ena.playGames  |########                        | 27/100
# ena.playGames  |########                        | 28/100
# ena.playGames  |#########                       | 29/100
# ena.playGames  |#########                       | 30/100
# ena.playGames  |#########                       | 31/100
# ena.playGames  |##########                      | 32/100
# ena.playGames  |##########                      | 33/100
# ena.playGames  |##########                      | 34/100
# ena.playGames  |###########                     | 35/100
# ena.playGames  |###########                     | 36/100
# ena.playGames  |###########                     | 37/100
# ena.playGames  |############                    | 38/100
# ena.playGames  |############                    | 39/100
# ena.playGames  |############                    | 40/100
# ena.playGames  |#############                   | 41/100
# ena.playGames  |#############                   | 42/100
# ena.playGames  |#############                   | 43/100
# ena.playGames  |##############                  | 44/100
# ena.playGames  |##############                  | 45/100
# ena.playGames  |##############                  | 46/100
# ena.playGames  |###############                 | 47/100
# ena.playGames  |###############                 | 48/100
# ena.playGames  |###############                 | 49/100
# ena.playGames  |################                | 50/100
# ena.playGames  |################                | 51/100
# ena.playGames  |################                | 52/100
# ena.playGames  |################                | 53/100
# ena.playGames  |#################               | 54/100
# ena.playGames  |#################               | 55/100
# ena.playGames  |#################               | 56/100
# ena.playGames  |##################              | 57/100
# ena.playGames  |##################              | 58/100
# ena.playGames  |##################              | 59/100
# ena.playGames  |###################             | 60/100
# ena.playGames  |###################             | 61/100
# ena.playGames  |###################             | 62/100
# ena.playGames  |####################            | 63/100
# ena.playGames  |####################            | 64/100
# ena.playGames  |####################            | 65/100
# ena.playGames  |#####################           | 66/100
# ena.playGames  |#####################           | 67/100
# ena.playGames  |#####################           | 68/100
# ena.playGames  |######################          | 69/100
# ena.playGames  |######################          | 70/100
# ena.playGames  |######################          | 71/100
# ena.playGames  |#######################         | 72/100
# ena.playGames  |#######################         | 73/100
# ena.playGames  |#######################         | 74/100
# ena.playGames  |########################        | 75/100
# ena.playGames  |########################        | 76/100
# ena.playGames  |########################        | 77/100
# ena.playGames  |########################        | 78/100
# ena.playGames  |#########################       | 79/100
# ena.playGames  |#########################       | 80/100
# ena.playGames  |#########################       | 81/100
# ena.playGames  |##########################      | 82/100
# ena.playGames  |##########################      | 83/100
# ena.playGames  |##########################      | 84/100
# ena.playGames  |###########################     | 85/100
# ena.playGames  |###########################     | 86/100
# ena.playGames  |###########################     | 87/100
# ena.playGames  |############################    | 88/100
# ena.playGames  |############################    | 89/100
# ena.playGames  |############################    | 90/100
# ena.playGames  |#############################   | 91/100
# ena.playGames  |#############################   | 92/100
# ena.playGames  |#############################   | 93/100
# ena.playGames  |##############################  | 94/100
# ena.playGames  |##############################  | 95/100
# ena.playGames  |##############################  | 96/100
# ena.playGames  |############################### | 97/100
# ena.playGames  |############################### | 98/100
# ena.playGames  |############################### | 99/100
#  Arena.playGames  |################################| 100/100
# 6
#
# ena.playGames  |                                | 1/100
# ena.playGames  |                                | 2/100
# ena.playGames  |                                | 3/100
# ena.playGames  |#                               | 4/100
# ena.playGames  |#                               | 5/100
# ena.playGames  |#                               | 6/100
# ena.playGames  |##                              | 7/100
# ena.playGames  |##                              | 8/100
# ena.playGames  |##                              | 9/100
# ena.playGames  |###                             | 10/100
# ena.playGames  |###                             | 11/100
# ena.playGames  |###                             | 12/100
# ena.playGames  |####                            | 13/100
# ena.playGames  |####                            | 14/100
# ena.playGames  |####                            | 15/100
# ena.playGames  |#####                           | 16/100
# ena.playGames  |#####                           | 17/100
# ena.playGames  |#####                           | 18/100
# ena.playGames  |######                          | 19/100
# ena.playGames  |######                          | 20/100
# ena.playGames  |######                          | 21/100
# ena.playGames  |#######                         | 22/100
# ena.playGames  |#######                         | 23/100
# ena.playGames  |#######                         | 24/100
# ena.playGames  |########                        | 25/100
# ena.playGames  |########                        | 26/100
# ena.playGames  |########                        | 27/100
# ena.playGames  |########                        | 28/100
# ena.playGames  |#########                       | 29/100
# ena.playGames  |#########                       | 30/100
# ena.playGames  |#########                       | 31/100
# ena.playGames  |##########                      | 32/100
# ena.playGames  |##########                      | 33/100
# ena.playGames  |##########                      | 34/100
# ena.playGames  |###########                     | 35/100
# ena.playGames  |###########                     | 36/100
# ena.playGames  |###########                     | 37/100
# ena.playGames  |############                    | 38/100
# ena.playGames  |############                    | 39/100
# ena.playGames  |############                    | 40/100
# ena.playGames  |#############                   | 41/100
# ena.playGames  |#############                   | 42/100
# ena.playGames  |#############                   | 43/100
# ena.playGames  |##############                  | 44/100
# ena.playGames  |##############                  | 45/100
# ena.playGames  |##############                  | 46/100
# ena.playGames  |###############                 | 47/100
# ena.playGames  |###############                 | 48/100
# ena.playGames  |###############                 | 49/100
# ena.playGames  |################                | 50/100
# ena.playGames  |################                | 51/100
# ena.playGames  |################                | 52/100
# ena.playGames  |################                | 53/100
# ena.playGames  |#################               | 54/100
# ena.playGames  |#################               | 55/100
# ena.playGames  |#################               | 56/100
# ena.playGames  |##################              | 57/100
# ena.playGames  |##################              | 58/100
# ena.playGames  |##################              | 59/100
# ena.playGames  |###################             | 60/100
# ena.playGames  |###################             | 61/100
# ena.playGames  |###################             | 62/100
# ena.playGames  |####################            | 63/100
# ena.playGames  |####################            | 64/100
# ena.playGames  |####################            | 65/100
# ena.playGames  |#####################           | 66/100
# ena.playGames  |#####################           | 67/100
# ena.playGames  |#####################           | 68/100
# ena.playGames  |######################          | 69/100
# ena.playGames  |######################          | 70/100
# ena.playGames  |######################          | 71/100
# ena.playGames  |#######################         | 72/100
# ena.playGames  |#######################         | 73/100
# ena.playGames  |#######################         | 74/100
# ena.playGames  |########################        | 75/100
# ena.playGames  |########################        | 76/100
# ena.playGames  |########################        | 77/100
# ena.playGames  |########################        | 78/100
# ena.playGames  |#########################       | 79/100
# ena.playGames  |#########################       | 80/100
# ena.playGames  |#########################       | 81/100
# ena.playGames  |##########################      | 82/100
# ena.playGames  |##########################      | 83/100
# ena.playGames  |##########################      | 84/100
# ena.playGames  |###########################     | 85/100
# ena.playGames  |###########################     | 86/100
# ena.playGames  |###########################     | 87/100
# ena.playGames  |############################    | 88/100
# ena.playGames  |############################    | 89/100
# ena.playGames  |############################    | 90/100
# ena.playGames  |#############################   | 91/100
# ena.playGames  |#############################   | 92/100
# ena.playGames  |#############################   | 93/100
# ena.playGames  |##############################  | 94/100
# ena.playGames  |##############################  | 95/100
# ena.playGames  |##############################  | 96/100
# ena.playGames  |############################### | 97/100
# ena.playGames  |############################### | 98/100
# ena.playGames  |############################### | 99/100
#  Arena.playGames  |################################| 100/100
# 7
#
# ena.playGames  |                                | 1/100
# ena.playGames  |                                | 2/100
# ena.playGames  |                                | 3/100
# ena.playGames  |#                               | 4/100
# ena.playGames  |#                               | 5/100
# ena.playGames  |#                               | 6/100
# ena.playGames  |##                              | 7/100
# ena.playGames  |##                              | 8/100
# ena.playGames  |##                              | 9/100
# ena.playGames  |###                             | 10/100
# ena.playGames  |###                             | 11/100
# ena.playGames  |###                             | 12/100
# ena.playGames  |####                            | 13/100
# ena.playGames  |####                            | 14/100
# ena.playGames  |####                            | 15/100
# ena.playGames  |#####                           | 16/100
# ena.playGames  |#####                           | 17/100
# ena.playGames  |#####                           | 18/100
# ena.playGames  |######                          | 19/100
# ena.playGames  |######                          | 20/100
# ena.playGames  |######                          | 21/100
# ena.playGames  |#######                         | 22/100
# ena.playGames  |#######                         | 23/100
# ena.playGames  |#######                         | 24/100
# ena.playGames  |########                        | 25/100
# ena.playGames  |########                        | 26/100
# ena.playGames  |########                        | 27/100
# ena.playGames  |########                        | 28/100
# ena.playGames  |#########                       | 29/100
# ena.playGames  |#########                       | 30/100
# ena.playGames  |#########                       | 31/100
# ena.playGames  |##########                      | 32/100
# ena.playGames  |##########                      | 33/100
# ena.playGames  |##########                      | 34/100
# ena.playGames  |###########                     | 35/100
# ena.playGames  |###########                     | 36/100
# ena.playGames  |###########                     | 37/100
# ena.playGames  |############                    | 38/100
# ena.playGames  |############                    | 39/100
# ena.playGames  |############                    | 40/100
# ena.playGames  |#############                   | 41/100
# ena.playGames  |#############                   | 42/100
# ena.playGames  |#############                   | 43/100
# ena.playGames  |##############                  | 44/100
# ena.playGames  |##############                  | 45/100
# ena.playGames  |##############                  | 46/100
# ena.playGames  |###############                 | 47/100
# ena.playGames  |###############                 | 48/100
# ena.playGames  |###############                 | 49/100
# ena.playGames  |################                | 50/100
# ena.playGames  |################                | 51/100
# ena.playGames  |################                | 52/100
# ena.playGames  |################                | 53/100
# ena.playGames  |#################               | 54/100
# ena.playGames  |#################               | 55/100
# ena.playGames  |#################               | 56/100
# ena.playGames  |##################              | 57/100
# ena.playGames  |##################              | 58/100
# ena.playGames  |##################              | 59/100
# ena.playGames  |###################             | 60/100
# ena.playGames  |###################             | 61/100
# ena.playGames  |###################             | 62/100
# ena.playGames  |####################            | 63/100
# ena.playGames  |####################            | 64/100
# ena.playGames  |####################            | 65/100
# ena.playGames  |#####################           | 66/100
# ena.playGames  |#####################           | 67/100
# ena.playGames  |#####################           | 68/100
# ena.playGames  |######################          | 69/100
# ena.playGames  |######################          | 70/100
# ena.playGames  |######################          | 71/100
# ena.playGames  |#######################         | 72/100
# ena.playGames  |#######################         | 73/100
# ena.playGames  |#######################         | 74/100
# ena.playGames  |########################        | 75/100
# ena.playGames  |########################        | 76/100
# ena.playGames  |########################        | 77/100
# ena.playGames  |########################        | 78/100
# ena.playGames  |#########################       | 79/100
# ena.playGames  |#########################       | 80/100
# ena.playGames  |#########################       | 81/100
# ena.playGames  |##########################      | 82/100
# ena.playGames  |##########################      | 83/100
# ena.playGames  |##########################      | 84/100
# ena.playGames  |###########################     | 85/100
# ena.playGames  |###########################     | 86/100
# ena.playGames  |###########################     | 87/100
# ena.playGames  |############################    | 88/100
# ena.playGames  |############################    | 89/100
# ena.playGames  |############################    | 90/100
# ena.playGames  |#############################   | 91/100
# ena.playGames  |#############################   | 92/100
# ena.playGames  |#############################   | 93/100
# ena.playGames  |##############################  | 94/100
# ena.playGames  |##############################  | 95/100
# ena.playGames  |##############################  | 96/100
# ena.playGames  |############################### | 97/100
# ena.playGames  |############################### | 98/100
# ena.playGames  |############################### | 99/100
#  Arena.playGames  |################################| 100/100
# 8
#
# ena.playGames  |                                | 1/100
# ena.playGames  |                                | 2/100
# ena.playGames  |                                | 3/100
# ena.playGames  |#                               | 4/100
# ena.playGames  |#                               | 5/100
# ena.playGames  |#                               | 6/100
# ena.playGames  |##                              | 7/100
# ena.playGames  |##                              | 8/100
# ena.playGames  |##                              | 9/100
# ena.playGames  |###                             | 10/100
# ena.playGames  |###                             | 11/100
# ena.playGames  |###                             | 12/100
# ena.playGames  |####                            | 13/100
# ena.playGames  |####                            | 14/100
# ena.playGames  |####                            | 15/100
# ena.playGames  |#####                           | 16/100
# ena.playGames  |#####                           | 17/100
# ena.playGames  |#####                           | 18/100
# ena.playGames  |######                          | 19/100
# ena.playGames  |######                          | 20/100
# ena.playGames  |######                          | 21/100
# ena.playGames  |#######                         | 22/100
# ena.playGames  |#######                         | 23/100
# ena.playGames  |#######                         | 24/100
# ena.playGames  |########                        | 25/100
# ena.playGames  |########                        | 26/100
# ena.playGames  |########                        | 27/100
# ena.playGames  |########                        | 28/100
# ena.playGames  |#########                       | 29/100
# ena.playGames  |#########                       | 30/100
# ena.playGames  |#########                       | 31/100
# ena.playGames  |##########                      | 32/100
# ena.playGames  |##########                      | 33/100
# ena.playGames  |##########                      | 34/100
# ena.playGames  |###########                     | 35/100
# ena.playGames  |###########                     | 36/100
# ena.playGames  |###########                     | 37/100
# ena.playGames  |############                    | 38/100
# ena.playGames  |############                    | 39/100
# ena.playGames  |############                    | 40/100
# ena.playGames  |#############                   | 41/100
# ena.playGames  |#############                   | 42/100
# ena.playGames  |#############                   | 43/100
# ena.playGames  |##############                  | 44/100
# ena.playGames  |##############                  | 45/100
# ena.playGames  |##############                  | 46/100
# ena.playGames  |###############                 | 47/100
# ena.playGames  |###############                 | 48/100
# ena.playGames  |###############                 | 49/100
# ena.playGames  |################                | 50/100
# ena.playGames  |################                | 51/100
# ena.playGames  |################                | 52/100
# ena.playGames  |################                | 53/100
# ena.playGames  |#################               | 54/100
# ena.playGames  |#################               | 55/100
# ena.playGames  |#################               | 56/100
# ena.playGames  |##################              | 57/100
# ena.playGames  |##################              | 58/100
# ena.playGames  |##################              | 59/100
# ena.playGames  |###################             | 60/100
# ena.playGames  |###################             | 61/100
# ena.playGames  |###################             | 62/100
# ena.playGames  |####################            | 63/100
# ena.playGames  |####################            | 64/100
# ena.playGames  |####################            | 65/100
# ena.playGames  |#####################           | 66/100
# ena.playGames  |#####################           | 67/100
# ena.playGames  |#####################           | 68/100
# ena.playGames  |######################          | 69/100
# ena.playGames  |######################          | 70/100
# ena.playGames  |######################          | 71/100
# ena.playGames  |#######################         | 72/100
# ena.playGames  |#######################         | 73/100
# ena.playGames  |#######################         | 74/100
# ena.playGames  |########################        | 75/100
# ena.playGames  |########################        | 76/100
# ena.playGames  |########################        | 77/100
# ena.playGames  |########################        | 78/100
# ena.playGames  |#########################       | 79/100
# ena.playGames  |#########################       | 80/100
# ena.playGames  |#########################       | 81/100
# ena.playGames  |##########################      | 82/100
# ena.playGames  |##########################      | 83/100
# ena.playGames  |##########################      | 84/100
# ena.playGames  |###########################     | 85/100
# ena.playGames  |###########################     | 86/100
# ena.playGames  |###########################     | 87/100
# ena.playGames  |############################    | 88/100
# ena.playGames  |############################    | 89/100
# ena.playGames  |############################    | 90/100
# ena.playGames  |#############################   | 91/100
# ena.playGames  |#############################   | 92/100
# ena.playGames  |#############################   | 93/100
# ena.playGames  |##############################  | 94/100
# ena.playGames  |##############################  | 95/100
# ena.playGames  |##############################  | 96/100
# ena.playGames  |############################### | 97/100
# ena.playGames  |############################### | 98/100
# ena.playGames  |############################### | 99/100
#  Arena.playGames  |################################| 100/100
# 9
#
# ena.playGames  |                                | 1/100
# ena.playGames  |                                | 2/100
# ena.playGames  |                                | 3/100
# ena.playGames  |#                               | 4/100
# ena.playGames  |#                               | 5/100
# ena.playGames  |#                               | 6/100
# ena.playGames  |##                              | 7/100
# ena.playGames  |##                              | 8/100
# ena.playGames  |##                              | 9/100
# ena.playGames  |###                             | 10/100
# ena.playGames  |###                             | 11/100
# ena.playGames  |###                             | 12/100
# ena.playGames  |####                            | 13/100
# ena.playGames  |####                            | 14/100
# ena.playGames  |####                            | 15/100
# ena.playGames  |#####                           | 16/100
# ena.playGames  |#####                           | 17/100
# ena.playGames  |#####                           | 18/100
# ena.playGames  |######                          | 19/100
# ena.playGames  |######                          | 20/100
# ena.playGames  |######                          | 21/100
# ena.playGames  |#######                         | 22/100
# ena.playGames  |#######                         | 23/100
# ena.playGames  |#######                         | 24/100
# ena.playGames  |########                        | 25/100
# ena.playGames  |########                        | 26/100
# ena.playGames  |########                        | 27/100
# ena.playGames  |########                        | 28/100
# ena.playGames  |#########                       | 29/100
# ena.playGames  |#########                       | 30/100
# ena.playGames  |#########                       | 31/100
# ena.playGames  |##########                      | 32/100
# ena.playGames  |##########                      | 33/100
# ena.playGames  |##########                      | 34/100
# ena.playGames  |###########                     | 35/100
# ena.playGames  |###########                     | 36/100
# ena.playGames  |###########                     | 37/100
# ena.playGames  |############                    | 38/100
# ena.playGames  |############                    | 39/100
# ena.playGames  |############                    | 40/100
# ena.playGames  |#############                   | 41/100
# ena.playGames  |#############                   | 42/100
# ena.playGames  |#############                   | 43/100
# ena.playGames  |##############                  | 44/100
# ena.playGames  |##############                  | 45/100
# ena.playGames  |##############                  | 46/100
# ena.playGames  |###############                 | 47/100
# ena.playGames  |###############                 | 48/100
# ena.playGames  |###############                 | 49/100
# ena.playGames  |################                | 50/100
# ena.playGames  |################                | 51/100
# ena.playGames  |################                | 52/100
# ena.playGames  |################                | 53/100
# ena.playGames  |#################               | 54/100
# ena.playGames  |#################               | 55/100
# ena.playGames  |#################               | 56/100
# ena.playGames  |##################              | 57/100
# ena.playGames  |##################              | 58/100
# ena.playGames  |##################              | 59/100
# ena.playGames  |###################             | 60/100
# ena.playGames  |###################             | 61/100
# ena.playGames  |###################             | 62/100
# ena.playGames  |####################            | 63/100
# ena.playGames  |####################            | 64/100
# ena.playGames  |####################            | 65/100
# ena.playGames  |#####################           | 66/100
# ena.playGames  |#####################           | 67/100
# ena.playGames  |#####################           | 68/100
# ena.playGames  |######################          | 69/100
# ena.playGames  |######################          | 70/100
# ena.playGames  |######################          | 71/100
# ena.playGames  |#######################         | 72/100
# ena.playGames  |#######################         | 73/100
# ena.playGames  |#######################         | 74/100
# ena.playGames  |########################        | 75/100
# ena.playGames  |########################        | 76/100
# ena.playGames  |########################        | 77/100
# ena.playGames  |########################        | 78/100
# ena.playGames  |#########################       | 79/100
# ena.playGames  |#########################       | 80/100
# ena.playGames  |#########################       | 81/100
# ena.playGames  |##########################      | 82/100
# ena.playGames  |##########################      | 83/100
# ena.playGames  |##########################      | 84/100
# ena.playGames  |###########################     | 85/100
# ena.playGames  |###########################     | 86/100
# ena.playGames  |###########################     | 87/100
# ena.playGames  |############################    | 88/100
# ena.playGames  |############################    | 89/100
# ena.playGames  |############################    | 90/100
# ena.playGames  |#############################   | 91/100
# ena.playGames  |#############################   | 92/100
# ena.playGames  |#############################   | 93/100
# ena.playGames  |##############################  | 94/100
# ena.playGames  |##############################  | 95/100
# ena.playGames  |##############################  | 96/100
# ena.playGames  |############################### | 97/100
# ena.playGames  |############################### | 98/100
# ena.playGames  |############################### | 99/100
#  Arena.playGames  |################################| 100/100

# %%
with open('qvalue_copy.txt','r') as data:
    qvalue=data.read()  
    
import ast    
Q=ast.literal_eval(qvalue)

# %%
with open('file.txt','r') as data:
    q= data.read()
    
import ast
Q=ast.literal_eval(q)
